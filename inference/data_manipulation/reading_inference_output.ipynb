# %%
import numpy as np

# Specify the path to the inference.npy file
file_path = '../done_inference_tiles/inference_ensemble_52VDQ.npy'

# Read the file using numpy's load function
inference_data = np.load(file_path)

print(inference_data.shape)
print(inference_data[0,1000:1010,1000:1010,0])
print(inference_data[0,1000:1010,1000:1010,1])
# Out:
# (1, 10980, 10980, 2)
# [[15.76560688 12.91799068  8.6264677   8.08103085  6.13148403  2.85458994
#    4.75886488  5.48706961  8.03451633 10.23737812]
#  [13.67730236 11.00587368  7.70545721  7.09501123  5.46338987  2.79362464
#    5.28692961  6.58451939  9.13608456 10.85046864]
#  [10.58197117  8.2510376   5.72763252  4.86595297  4.2324543   2.97106385
#    4.47258997  5.57350206  7.1198945   8.35104275]
#  [ 7.59650183  6.26553917  5.34419537  5.14557219  4.60508537  2.73312497
#    4.06117773  4.68539381  5.76715183  6.34742689]
#  [ 5.85651636  5.21855688  3.91275835  3.47267795  2.77395105  2.73034191
#    3.8140645   4.38118362  5.16827679  5.54242277]
#  [ 5.96156645  5.48885584  4.92859983  5.40714359  3.77072144  3.09669137
#    3.84050059  4.4665308   5.95104504  6.55301046]
#  [ 7.62066793  6.40036774  6.05761814  6.64150095  4.5850749   3.80957103
#    5.29688501  5.29868174  7.02144575  8.43256092]
# ...

# %%
import numpy as np

# count = np.count_nonzero((inference_data != 0) & (inference_data < 1000))
count_nonzero = np.count_nonzero((inference_data))
mean = np.mean(inference_data[inference_data != 0])
count_zero = np.count_nonzero(inference_data== 0)

print(mean)
print(count_nonzero)
print(count_zero)
# Out:
# 10.924952450040093
# 241120800
# 0

# %%
bands = ['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B09', 'B11', 'B12']
print(sorted(bands))
# Out:
# ['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B09', 'B11', 'B12', 'B8A']

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a numpy array called 'image_array'
# Replace 'image_array' with your actual numpy array
image_array = np.load('../done_inference_tiles/inference_ensemble_52VDQ.npy')
image_array = np.moveaxis(image_array[0], 2, 0)
# Display the grayscale image
plt.figure(figsize=(20, 20))
plt.imshow(image_array[0], cmap='gray')
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a numpy array called 'image_array'
# Replace 'image_array' with your actual numpy array
image_array = np.load('../done_inference_tiles/inference_ensemble_52VDQ.npy')
image_array = np.moveaxis(image_array[0], 2, 0)
# Display the grayscale image
plt.figure(figsize=(20, 20))
plt.imshow(image_array[1], cmap='gray')
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a numpy array called 'image_array'
# Replace 'image_array' with your actual numpy array
image_array = np.load('../done_inference_tiles/debugging_inference_ensemble_52VEQ.npy')
image_array = np.moveaxis(image_array[0], 2, 0)
# Display the grayscale image
plt.figure(figsize=(20, 20))
plt.imshow(image_array[1, 0:30, 0:30], cmap='gray')
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a numpy array called 'image_array'
# Replace 'image_array' with your actual numpy array
image_array = np.load('../done_inference_tiles/debugging_inference_ensemble_52VEQ.npy')
image_array = np.moveaxis(image_array[0], 2, 0)
image_array = image_array[1, 0:30, 0:30]
print(image_array.shape)
print(image_array[7,7], image_array[7,22])
print(image_array[22,7], image_array[22,22])
image_array = image_array[7::15,7::15]
print(image_array)
# Out:
# (30, 30)
# 44.45392990112305 43.468753814697266
# 50.46861267089844 48.608524322509766
# [[44.4539299  43.46875381]
#  [50.46861267 48.60852432]]
